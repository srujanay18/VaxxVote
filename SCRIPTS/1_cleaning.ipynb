# %% [markdown]
# <a href="https://colab.research.google.com/github/srujanay18/VaxxVote/blob/main/SCRIPTS/1_cleaning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Import packages

# %%
# import necessary packages for cleaning
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import seaborn as sns

# %% [markdown]
# # Create the president dataframe - which includes their Year Served, Name, and Party affiliated

# %%
# create a dataframe including presidents and the year/terms served since 1980-2025 and their political party affiliation
presidents_data = {
    'year': list(range(1980, 2025)),
    'US president': [
        'Jimmy Carter', 'Ronald Reagan', 'Ronald Reagan', 'Ronald Reagan', 'Ronald Reagan',
        'Ronald Reagan', 'Ronald Reagan', 'Ronald Reagan', 'George H. W. Bush', 'George H. W. Bush',
        'George H. W. Bush', 'George H. W. Bush', 'Bill Clinton', 'Bill Clinton', 'Bill Clinton',
        'Bill Clinton', 'Bill Clinton', 'Bill Clinton', 'Bill Clinton', 'Bill Clinton',
        'George W. Bush', 'George W. Bush', 'George W. Bush', 'George W. Bush', 'George W. Bush',
        'George W. Bush', 'George W. Bush', 'George W. Bush', 'Barack Obama', 'Barack Obama',
        'Barack Obama', 'Barack Obama', 'Barack Obama', 'Barack Obama', 'Barack Obama', 'Barack Obama',
        'Donald Trump', 'Donald Trump', 'Donald Trump', 'Donald Trump', 'Joe Biden', 'Joe Biden',
        'Joe Biden', 'Joe Biden', 'Joe Biden'
    ],
    'party': [
        'Democrat', 'Republican', 'Republican', 'Republican', 'Republican',
        'Republican', 'Republican', 'Republican', 'Republican', 'Republican',
        'Republican', 'Republican', 'Democrat', 'Democrat', 'Democrat',
        'Democrat', 'Democrat', 'Democrat', 'Democrat', 'Democrat',
        'Republican', 'Republican', 'Republican', 'Republican', 'Republican',
        'Republican', 'Republican', 'Republican', 'Democrat', 'Democrat',
        'Democrat', 'Democrat', 'Democrat', 'Democrat', 'Democrat', 'Democrat',
        'Republican', 'Republican', 'Republican', 'Republican', 'Democrat', 'Democrat',
        'Democrat', 'Democrat', 'Democrat'
    ]
}

presidents_df = pd.DataFrame(presidents_data)
presidents_df['year'] = presidents_df['year'].astype(int)

display(presidents_df.head())
# Out:
#    year   US president       party
# 0  1980   Jimmy Carter    Democrat
# 1  1981  Ronald Reagan  Republican
# 2  1982  Ronald Reagan  Republican
# 3  1983  Ronald Reagan  Republican
# 4  1984  Ronald Reagan  Republican

# %% [markdown]
# # Read in the vaccination datasets for Rubella, DTP, Measles, and Influenza

# %%
# read all the vaccination datasets and display their first 4 rows
rubella_df = pd.read_excel("/content/Rubella vaccination coverage 2025-20-10 09-42 UTC.xlsx")
dtp_df = pd.read_excel("/content/Diphtheria tetanus toxoid and pertussis (DTP) vaccination coverage 2025-15-10 15-11 UTC (2).xlsx")
measles_df = pd.read_excel("/content/Measles vaccination coverage 2025-15-10 14-12 UTC.xlsx")
influenza_df = pd.read_csv("/content/Influenza Vaccine Doses Distributed in the United States, By Season (1).csv")

print("Rubella Head:")
display(rubella_df.head())

print("DTP Head:")
display(dtp_df.head())

print("Measles Head:")
display(measles_df.head())

print("Influenza Head:")
display(influenza_df.head())
# Out:
# Rubella Head:
#        GROUP CODE                      NAME    YEAR ANTIGEN  \
# 0  COUNTRIES  USA  United States of America  2024.0    RCV1
# 1  COUNTRIES  USA  United States of America  2023.0    RCV1
# 2  COUNTRIES  USA  United States of America  2023.0    RCV1
# 3  COUNTRIES  USA  United States of America  2023.0    RCV1
# 4  COUNTRIES  USA  United States of America  2022.0    RCV1
#
#                     ANTIGEN_DESCRIPTION COVERAGE_CATEGORY  \
# 0  Rubella-containing vaccine, 1st dose            WUENIC
# 1  Rubella-containing vaccine, 1st dose             ADMIN
# 2  Rubella-containing vaccine, 1st dose          OFFICIAL
# 3  Rubella-containing vaccine, 1st dose            WUENIC
# 4  Rubella-containing vaccine, 1st dose             ADMIN
#
#                        COVERAGE_CATEGORY_DESCRIPTION  TARGET_NUMBER  DOSES  \
# 0  WHO/UNICEF Estimates of National Immunization ...            NaN    NaN
# 1                            Administrative coverage            NaN    NaN
# ...

# %% [markdown]
# # Cleaning Process Part 1 - drop the columns unneeded for analysis/model: TARGET_NUMBER and DOSES. Do this for the Rubella, DTP, and Measles datasets.

# %%
# drop the unneccesary columns for analysis: TARGET_NUMBER and DOSES
rubella_df = rubella_df.drop(columns=['TARGET_NUMBER', 'DOSES'])
dtp_df = dtp_df.drop(columns=['TARGET_NUMBER', 'DOSES'])
measles_df = measles_df.drop(columns=['TARGET_NUMBER', 'DOSES'])

print("Rubella Head after dropping columns:")
display(rubella_df.head())

print("DTP Head after dropping columns:")
display(dtp_df.head())

print("Measles Head after dropping columns:")
display(measles_df.head())
# Out:
# Rubella Head after dropping columns:
#        GROUP CODE                      NAME    YEAR ANTIGEN  \
# 0  COUNTRIES  USA  United States of America  2024.0    RCV1
# 1  COUNTRIES  USA  United States of America  2023.0    RCV1
# 2  COUNTRIES  USA  United States of America  2023.0    RCV1
# 3  COUNTRIES  USA  United States of America  2023.0    RCV1
# 4  COUNTRIES  USA  United States of America  2022.0    RCV1
#
#                     ANTIGEN_DESCRIPTION COVERAGE_CATEGORY  \
# 0  Rubella-containing vaccine, 1st dose            WUENIC
# 1  Rubella-containing vaccine, 1st dose             ADMIN
# 2  Rubella-containing vaccine, 1st dose          OFFICIAL
# 3  Rubella-containing vaccine, 1st dose            WUENIC
# 4  Rubella-containing vaccine, 1st dose             ADMIN
#
#                        COVERAGE_CATEGORY_DESCRIPTION  COVERAGE
# 0  WHO/UNICEF Estimates of National Immunization ...      92.0
# 1                            Administrative coverage       NaN
# ...

# %% [markdown]
# # Cleaning Process Part 2 - drop the rows/observations where COVERAGE_CATEGORY == 'WUENIC' and COVERAGE_CATEGORY_DESCRIPTION == 'WHO/UNICEF Estimates of National Immunization Coverage'. Do this for the Rubella, DTP, and Measles  datasets.

# %%
# filter to only show observations where COVERAGE_CATEGORY == 'WUENIC' and COVERAGE_CATEGORY_DESCRIPTION == 'WHO/UNICEF Estimates of National Immunization Coverage'
rubella_df_filtered = rubella_df[(rubella_df['COVERAGE_CATEGORY'] == 'WUENIC') & (rubella_df['COVERAGE_CATEGORY_DESCRIPTION'] == 'WHO/UNICEF Estimates of National Immunization Coverage')]
dtp_df_filtered = dtp_df[(dtp_df['COVERAGE_CATEGORY'] == 'WUENIC') & (dtp_df['COVERAGE_CATEGORY_DESCRIPTION'] == 'WHO/UNICEF Estimates of National Immunization Coverage')]
measles_df_filtered = measles_df[(measles_df['COVERAGE_CATEGORY'] == 'WUENIC') & (measles_df['COVERAGE_CATEGORY_DESCRIPTION'] == 'WHO/UNICEF Estimates of National Immunization Coverage')]

print("Filtered Rubella Head:")
display(rubella_df_filtered.head())

print("Filtered DTP Head:")
display(dtp_df_filtered.head())

print("Filtered Measles Head:")
display(measles_df_filtered.head())
# Out:
# Filtered Rubella Head:
#         GROUP CODE                      NAME    YEAR ANTIGEN  \
# 0   COUNTRIES  USA  United States of America  2024.0    RCV1
# 3   COUNTRIES  USA  United States of America  2023.0    RCV1
# 6   COUNTRIES  USA  United States of America  2022.0    RCV1
# 9   COUNTRIES  USA  United States of America  2021.0    RCV1
# 12  COUNTRIES  USA  United States of America  2020.0    RCV1
#
#                      ANTIGEN_DESCRIPTION COVERAGE_CATEGORY  \
# 0   Rubella-containing vaccine, 1st dose            WUENIC
# 3   Rubella-containing vaccine, 1st dose            WUENIC
# 6   Rubella-containing vaccine, 1st dose            WUENIC
# 9   Rubella-containing vaccine, 1st dose            WUENIC
# 12  Rubella-containing vaccine, 1st dose            WUENIC
#
#                         COVERAGE_CATEGORY_DESCRIPTION  COVERAGE
# 0   WHO/UNICEF Estimates of National Immunization ...      92.0
# 3   WHO/UNICEF Estimates of National Immunization ...      92.0
# ...

# %% [markdown]
# # Cleaning Process Part 3 - combine the cleaned Rubella, DTP, and Measles datasets into one dataframe

# %%
# combine the cleaned Rubella, DTP, and Measles datasets into one dataframe
merged_vaccines_df = rubella_df_filtered.merge(dtp_df_filtered, on='YEAR', how='outer', suffixes=('_Rubella', '_DTP'))
merged_vaccines_df = merged_vaccines_df.merge(measles_df_filtered, on='YEAR', how='outer', suffixes=('', '_Measles'))

# Rename the 'COVERAGE' column from the measles merge
merged_vaccines_df = merged_vaccines_df.rename(columns={'COVERAGE': 'COVERAGE_Measles'})

display(merged_vaccines_df.head())
# Out:
#   GROUP_Rubella CODE_Rubella              NAME_Rubella    YEAR  \
# 0     COUNTRIES          USA  United States of America  1980.0
# 1     COUNTRIES          USA  United States of America  1981.0
# 2     COUNTRIES          USA  United States of America  1982.0
# 3     COUNTRIES          USA  United States of America  1983.0
# 4     COUNTRIES          USA  United States of America  1984.0
#
#   ANTIGEN_Rubella           ANTIGEN_DESCRIPTION_Rubella  \
# 0            RCV1  Rubella-containing vaccine, 1st dose
# 1            RCV1  Rubella-containing vaccine, 1st dose
# 2            RCV1  Rubella-containing vaccine, 1st dose
# 3            RCV1  Rubella-containing vaccine, 1st dose
# 4            RCV1  Rubella-containing vaccine, 1st dose
#
#   COVERAGE_CATEGORY_Rubella  \
# 0                    WUENIC
# 1                    WUENIC
# 2                    WUENIC
# 3                    WUENIC
# 4                    WUENIC
#
# ...

# %%
vaccination_dfs = [rubella_df, dtp_df, measles_df]

combined_vaccination_df = pd.concat(vaccination_dfs, ignore_index=True)

# Filter to keep only rows where COVERAGE_CATEGORY is 'WUENIC'
combined_vaccination_df = combined_vaccination_df[combined_vaccination_df['COVERAGE_CATEGORY'] == 'WUENIC'].copy()

# Filter to keep only rows with '1st dose' in ANTIGEN_DESCRIPTION
combined_vaccination_df = combined_vaccination_df[combined_vaccination_df['ANTIGEN_DESCRIPTION'].str.contains('1st dose')].copy()


combined_vaccination_df.dropna(inplace=True)

combined_vaccination_df = combined_vaccination_df.rename(columns={'YEAR': 'year'})

combined_vaccination_df['year'] = combined_vaccination_df['year'].astype(int)

display(combined_vaccination_df.head())
display(combined_vaccination_df.info())
# Out:
#         GROUP CODE                      NAME  year ANTIGEN  \
# 0   COUNTRIES  USA  United States of America  2024    RCV1
# 3   COUNTRIES  USA  United States of America  2023    RCV1
# 6   COUNTRIES  USA  United States of America  2022    RCV1
# 9   COUNTRIES  USA  United States of America  2021    RCV1
# 12  COUNTRIES  USA  United States of America  2020    RCV1
#
#                      ANTIGEN_DESCRIPTION COVERAGE_CATEGORY  \
# 0   Rubella-containing vaccine, 1st dose            WUENIC
# 3   Rubella-containing vaccine, 1st dose            WUENIC
# 6   Rubella-containing vaccine, 1st dose            WUENIC
# 9   Rubella-containing vaccine, 1st dose            WUENIC
# 12  Rubella-containing vaccine, 1st dose            WUENIC
#
#                         COVERAGE_CATEGORY_DESCRIPTION  COVERAGE
# 0   WHO/UNICEF Estimates of National Immunization ...      92.0
# 3   WHO/UNICEF Estimates of National Immunization ...      92.0
# ...

# %% [markdown]
# # Cleaning Process Part 4 - due to influenza having different columns and looking at dosage only, combine the Influenza dataset with the presidents dataframe.

# %%
# combine the Influenza dataset with the presidents dataframe
influenza_df['year'] = influenza_df['Date'].apply(lambda x: int(x.split('-')[0]))
merged_influenza_df = pd.merge(influenza_df, presidents_df, on='year', how='inner')

print("Merged Influenza Data Head:")
display(merged_influenza_df.head())
# Out:
# Merged Influenza Data Head:
#         Date  Millions of Doses  year   US president       party
# 0  1980-1981               12.4  1980   Jimmy Carter    Democrat
# 1  1981-1982               19.8  1981  Ronald Reagan  Republican
# 2  1982-1983               17.0  1982  Ronald Reagan  Republican
# 3  1983-1984               17.9  1983  Ronald Reagan  Republican
# 4  1984-1985               14.2  1984  Ronald Reagan  Republican

# %% [markdown]
# # Cleaning Process Part 5 - due to influenza having different columns and looking at dosage only, combine the Rubella, DTP, and Measles merged dataframe with the presidents dataframe.

# %%
# combine the Rubella, DTP, and Measles merged dataframe with the presidents dataframe
merged_df = pd.merge(combined_vaccination_df, presidents_df, on='year', how='inner')
display(merged_df.head())
# Out:
#        GROUP CODE                      NAME  year ANTIGEN  \
# 0  COUNTRIES  USA  United States of America  2024    RCV1
# 1  COUNTRIES  USA  United States of America  2023    RCV1
# 2  COUNTRIES  USA  United States of America  2022    RCV1
# 3  COUNTRIES  USA  United States of America  2021    RCV1
# 4  COUNTRIES  USA  United States of America  2020    RCV1
#
#                     ANTIGEN_DESCRIPTION COVERAGE_CATEGORY  \
# 0  Rubella-containing vaccine, 1st dose            WUENIC
# 1  Rubella-containing vaccine, 1st dose            WUENIC
# 2  Rubella-containing vaccine, 1st dose            WUENIC
# 3  Rubella-containing vaccine, 1st dose            WUENIC
# 4  Rubella-containing vaccine, 1st dose            WUENIC
#
#                        COVERAGE_CATEGORY_DESCRIPTION  COVERAGE US president  \
# 0  WHO/UNICEF Estimates of National Immunization ...      92.0    Joe Biden
# 1  WHO/UNICEF Estimates of National Immunization ...      92.0    Joe Biden
# ...

# %% [markdown]
# # Cleaning Process Part 6 - download the final dataframes as csv files

# %%
# download the 3 vaccinations and presidents datasets as a csv file
merged_df.to_csv('merged_vaccination_presidents_data.csv', index=False)

# %%
# download the influenza and presidents datasets as a csv file
merged_influenza_df.to_csv('merged_influenza_presidents_data.csv', index=False)
